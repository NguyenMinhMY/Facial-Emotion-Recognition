# %%
import numpy as np
import tensorflow as tf
from keras.layers import Flatten,Activation,Input,Add,Dense,Conv2D,ZeroPadding2D, \
    MaxPooling2D,AveragePooling2D,ZeroPadding2D,BatchNormalization
from keras.models import Model, load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
from Resnet50 import ResNet50
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam, SGD

# %%
train_data_dir = 'train/'
test_data_dir = 'test/'
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# %%
train_datagen = image.ImageDataGenerator(
    rescale= 1 / 255.0,
    shear_range= 0.2,
    rotation_range=40,
    zoom_range=0.2,
    horizontal_flip= True,
    fill_mode= 'nearest',
    width_shift_range= 10,
    height_shift_range= 10,
)
test_datagen = image.ImageDataGenerator(rescale=1/255.0)

# %%
train_generator = train_datagen.flow_from_directory(
    directory=train_data_dir,
    color_mode= 'grayscale',
    target_size= (48, 48),
    batch_size= 32,
    class_mode= 'categorical',
    shuffle= True
)

test_generator = test_datagen.flow_from_directory(
    directory=test_data_dir,
    color_mode='grayscale',
    target_size=(48,48),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer._decayed_lr(tf.float32) # I use ._decayed_lr method instead of .lr
    return lr

# %%
schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    2.6808e-04, 898 * 5, 0.8, staircase=False, name=None
)
optimizer = Adam(learning_rate=schedule)
lr_metric = get_lr_metric(optimizer)

# %%
loaded_model = load_model('thirty-ep-5894per', custom_objects={'lr': lr_metric}, compile=False)

# %%
#loaded_model.optimizer.learning_rate = 0.0000001
print(loaded_model.optimizer._decayed_lr('float32').numpy())

# %%
loaded_model.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy', lr_metric])

# %%
hist = loaded_model.fit(train_generator, epochs=20)
# Out:
# Epoch 1/20
# 898/898 [==============================] - 1198s 1s/step - loss: 1.1494 - accuracy: 0.5647 - lr: 2.6218e-04
# Epoch 2/20
# 898/898 [==============================] - 1174s 1s/step - loss: 1.1230 - accuracy: 0.5743 - lr: 2.5074e-04
# Epoch 3/20
# 898/898 [==============================] - 1171s 1s/step - loss: 1.1105 - accuracy: 0.5794 - lr: 2.3979e-04
# Epoch 4/20
# 898/898 [==============================] - 1175s 1s/step - loss: 1.0983 - accuracy: 0.5847 - lr: 2.2933e-04
# Epoch 5/20
# 898/898 [==============================] - 1140s 1s/step - loss: 1.0873 - accuracy: 0.5880 - lr: 2.1932e-04
# Epoch 6/20
# 898/898 [==============================] - 1146s 1s/step - loss: 1.0721 - accuracy: 0.5949 - lr: 2.0974e-04
# Epoch 7/20
# 898/898 [==============================] - 1184s 1s/step - loss: 1.0644 - accuracy: 0.5995 - lr: 2.0059e-04
# Epoch 8/20
# 898/898 [==============================] - 1182s 1s/step - loss: 1.0544 - accuracy: 0.6016 - lr: 1.9183e-04
# Epoch 9/20
# 898/898 [==============================] - 1183s 1s/step - loss: 1.0496 - accuracy: 0.6022 - lr: 1.8346e-04
# Epoch 10/20
# 898/898 [==============================] - 1160s 1s/step - loss: 1.0430 - accuracy: 0.6059 - lr: 1.7545e-04
# Epoch 11/20
# 898/898 [==============================] - 1113s 1s/step - loss: 1.0288 - accuracy: 0.6110 - lr: 1.6779e-04
# Epoch 12/20
# 898/898 [==============================] - 1122s 1s/step - loss: 1.0213 - accuracy: 0.6143 - lr: 1.6047e-04
# Epoch 13/20
# 898/898 [==============================] - 1137s 1s/step - loss: 1.0150 - accuracy: 0.6186 - lr: 1.5347e-04
# Epoch 14/20
# 898/898 [==============================] - 1168s 1s/step - loss: 1.0072 - accuracy: 0.6215 - lr: 1.4677e-04
# Epoch 15/20
# 898/898 [==============================] - 1165s 1s/step - loss: 1.0024 - accuracy: 0.6205 - lr: 1.4036e-04
# Epoch 16/20
# 898/898 [==============================] - 1152s 1s/step - loss: 0.9976 - accuracy: 0.6249 - lr: 1.3424e-04
# Epoch 17/20
# 898/898 [==============================] - 1122s 1s/step - loss: 0.9891 - accuracy: 0.6246 - lr: 1.2838e-04
# Epoch 18/20
# 898/898 [==============================] - 1111s 1s/step - loss: 0.9818 - accuracy: 0.6287 - lr: 1.2277e-04
# Epoch 19/20
# 898/898 [==============================] - 1082s 1s/step - loss: 0.9811 - accuracy: 0.6319 - lr: 1.1741e-04
# Epoch 20/20
# 898/898 [==============================] - 1076s 1s/step - loss: 0.9686 - accuracy: 0.6323 - lr: 1.1229e-04

# %%
#Predict time!

img, label = test_generator.next()
predictions = loaded_model.predict(img)
predictions = np.argmax(predictions, axis=1)
print(predictions.shape)
test_lbl = np.argmax(label, axis=1)
for i in range(10):
    imagea = img[i]
    true_labl = labels[test_lbl[i]]
    plt.imshow(imagea, cmap='gray')
    plt.title(labels[predictions[i]])
    print(f'True: {true_labl}')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 32ms/step
# (32,)
# True: Neutral
# True: Angry
# True: Happy
# True: Happy
# True: Fear
# True: Happy
# True: Surprise
# True: Neutral
# True: Neutral
# True: Sad

# %%
test_loss, test_acc, lr = loaded_model.evaluate(test_generator, verbose=1) 

print('Test accuracy:', test_acc)
# Out:
# 225/225 [==============================] - 96s 413ms/step - loss: 0.9798 - accuracy: 0.6381 - lr: 1.0981e-04
# Test accuracy: 0.6380607485771179

# %%
hist = loaded_model.save('fifty-ep-6323per', save_format='tf')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: fifty-ep-6323per\assets
# INFO:tensorflow:Assets written to: fifty-ep-6323per\assets

# %%
loss = hist.history['loss']
# = hist.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs,loss,label='Training loss')
#.plot(epochs, val_loss,'r',label='Validation loss')
plt.plot('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\nam18\OneDrive\Desktop\New folder\conti.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nam18/OneDrive/Desktop/New%20folder/conti.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> loss = hist.history['loss']
#       <a href='vscode-notebook-cell:/c%3A/Users/nam18/OneDrive/Desktop/New%20folder/conti.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> # = hist.history['val_loss']
#       <a href='vscode-notebook-cell:/c%3A/Users/nam18/OneDrive/Desktop/New%20folder/conti.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> epochs = range(1, len(loss) + 1)
#
# AttributeError: 'NoneType' object has no attribute 'history'
